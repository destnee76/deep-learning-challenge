# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df= application_df.drop(columns= ['EIN', 'NAME'])

# %%
# Display first 5 rows
application_df.head(5)
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
type_counts = application_df.APPLICATION_TYPE.value_counts()
type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = type_counts['T10']
application_types_to_replace = type_counts[type_counts < cutoff].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df.CLASSIFICATION.value_counts()
class_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts_gt_1 = class_counts[class_counts > 1]
class_counts_gt_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = class_counts['C2100']
classifications_to_replace = class_counts[class_counts < cutoff].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)

# %%
dummies_df.columns
# Out:
# Index(['STATUS', 'ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_Other',
#        'APPLICATION_TYPE_T10', 'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3',
#        'APPLICATION_TYPE_T4', 'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6',
#        'APPLICATION_TYPE_T7', 'APPLICATION_TYPE_T8',
#        'AFFILIATION_CompanySponsored', 'AFFILIATION_Family/Parent',
#        'AFFILIATION_Independent', 'AFFILIATION_National', 'AFFILIATION_Other',
#        'AFFILIATION_Regional', 'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200',
#        'CLASSIFICATION_C2000', 'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000',
#        'CLASSIFICATION_Other', 'USE_CASE_CommunityServ', 'USE_CASE_Heathcare',
#        'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['IS_SUCCESSFUL']
X = dummies_df.drop(['IS_SUCCESSFUL'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Attempt 1

# %%
# Define the model - deep neural net
number_input_features = X_train.shape[1]
hidden_nodes_layer1 = 64  # Adjusted number of neurons
hidden_nodes_layer2 = 32  # Adjusted number of neurons

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                2816
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 4929 (19.25 KB)
# Trainable params: 4929 (19.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5722 - accuracy: 0.7191
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5548 - accuracy: 0.7314
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7313
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7331
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5496 - accuracy: 0.7341
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5489 - accuracy: 0.7349
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7346
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5466 - accuracy: 0.7353
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7347
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5539 - accuracy: 0.7268 - 315ms/epoch - 1ms/step
# Loss: 0.5538591742515564, Accuracy: 0.7267638444900513

# %% [markdown]
# **1st Attempt Accuracy - 72.676%**

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Attempt 2

# %%
# Define the model - deep neural net
number_input_features = X_train.shape[1]
hidden_nodes_layer1 = 20  # Adjusted number of neurons
hidden_nodes_layer2 = 20  # Adjusted number of neurons

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")) # Changed activation to "tanh"

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh")) # Changed activation to "tanh"

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 20)                880
#
#  dense_4 (Dense)             (None, 20)                420
#
#  dense_5 (Dense)             (None, 1)                 21
#
# ...
# Total params: 1321 (5.16 KB)
# Trainable params: 1321 (5.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5802 - accuracy: 0.7148
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5608 - accuracy: 0.7278
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5561 - accuracy: 0.7316
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7311
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7308
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7335
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.7331
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7328
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5484 - accuracy: 0.7334
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5530 - accuracy: 0.7230 - 292ms/epoch - 1ms/step
# Loss: 0.5529941916465759, Accuracy: 0.7230320572853088

# %% [markdown]
# **2nd Attempt Accuracy - 72.303%**

# %% [markdown]
# ## Compile, Train and Evaluate the Model - Attempt 3

# %%
# Define the model - deep neural net
number_input_features = X_train.shape[1]
hidden_nodes_layer1 = 50  # Adjusted number of neurons
hidden_nodes_layer2 = 30  # Adjusted number of neurons
hidden_nodes_layer3 = 10 # added extra layer

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))  # Changed activation to "sigmoid"

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))  # Changed activation to "sigmoid"

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))  # Changed activation to "tanh"

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_17 (Dense)            (None, 50)                2200
#
#  dense_18 (Dense)            (None, 30)                1530
#
#  dense_19 (Dense)            (None, 10)                310
#
#  dense_20 (Dense)            (None, 1)                 11
#
# ...
# Total params: 4051 (15.82 KB)
# Trainable params: 4051 (15.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model with adjusted epochs
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)  # Changed epochs to 50
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5953 - accuracy: 0.7039
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5729 - accuracy: 0.7254
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5660 - accuracy: 0.7268
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5618 - accuracy: 0.7280
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5586 - accuracy: 0.7286
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5570 - accuracy: 0.7303
# Epoch 7/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5545 - accuracy: 0.7313
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7305
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7320
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5521 - accuracy: 0.7266 - 278ms/epoch - 1ms/step
# Loss: 0.5521060228347778, Accuracy: 0.7266472578048706

# %% [markdown]
# **3rd Attempt Accuracy - 72.664%**

# %%
# Export our model to HDF5 file
filepath = r"/content/drive/MyDrive/Colab Notebooks/AlphabetSoupCharity_Optimization.h5"
nn.save(filepath, save_format='h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
